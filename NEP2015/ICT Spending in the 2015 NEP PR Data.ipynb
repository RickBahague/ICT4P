# %% [markdown]
# This is the accompanying notebook for all data used in the analysis of NEP 2015
# You can modify this to analyze other part of the NEP 2015.
# This notebook is focused on the ICT component.
#
# Author: Rick Bahague / rick (at) cp-union (dot) com.
#         http://www.cp-union.com
#
# Download datasets from the DBM website.

# %%
# %matplotlib inline
import pandas as pd
from pylab import *
import mpld3

rcParams['figure.figsize'] = 12, 6
pd.set_option('display.max_rows',500)

mpld3.enable_notebook()

DATA_PATH = "../data/"

#durl = 'http://datasets.flowingdata.com/crimeRatesByState2005.csv'
#rdata = genfromtxt(durl,dtype='S8,f,f,f,f,f,f,f,i',delimiter=',')

# %% [markdown]
# ### Load Data for Automatic Appropriation & Proposed Appropriation

# %%
#Data taken from DBM Site
auto_approp = pd.read_csv(DATA_PATH + "2015 NEP-Proposed-Automatic.csv")
auto_approp.fillna(value=0,inplace=True)
new_approp = pd.read_csv(DATA_PATH + "2015 NEP-Proposed.csv")
new_approp.fillna(value=0,inplace=True)

#rename columns for clarity
new_approp.columns = [u'uacs_dpt_id', u'Department', u'uacs_agy_id', u'Agency', 
         u'uacs_fpap_id', u'Description', u'operdiv', u'operunit', u'uacs_oper_dsc', u'fndsrc', 
         u'Source', u'uacs_exp_cd', u'Category', u'uacs_sobj_cd', 
         u'Objective', u'Amount']
auto_approp.columns = [u'uacs_dpt_id', u'Department', u'uacs_agy_id', u'Agency', 
         u'uacs_fpap_id', u'Description', u'operdiv', u'operunit', u'uacs_oper_dsc', u'fndsrc', 
         u'Source', u'uacs_exp_cd', u'Category', u'uacs_sobj_cd', 
         u'Objective', u'Amount']

#select data for analysis
auto_approp_data = auto_approp[auto_approp.Amount>0][['Department','Agency','Description','Source','Category','Objective','Amount']]
auto_approp_data['NEP'] = 'AUTO'
new_approp_data = new_approp[new_approp.Amount>0][['Department','Agency','Description','Source','Category','Objective','Amount']]
new_approp_data['NEP'] = 'NEW'
all_data = auto_approp_data.append(new_approp_data)
all_data[ [u'NEP',u'Department', u'Agency', u'Description', u'Category','Source', u'Objective', u'Amount']].to_csv('data.csv')

# %% [markdown]
# ### Total New and Automatic Appropriation

# %%
all_data['Amount'].sum()
# Out:
# 2606000000.0

# %% [markdown]
# Sa kabuuan, mas malaki ng Php 341.7B ang gagastusin ng Administrasyon sa susunod na taon kung ihahambing sa budget ngayong taon.

# %% [markdown]
# ### ICT Budget Items Per Department

# %% [markdown]
# The following lists budget items that can be categorized as ICT spending. Note that there are budget items that are actually almost the same but are treated separately and given separate budgets. Example: ICT Software and Computer Software, Information and Communication Technology Equipment and ICT Machinery and Equipment

# %%
ICT_items = [
"Information and Communication Technology Equipment",
"Communication Equipment",
"ICT Office Supplies",
"ICT Software",
"Cloud Computing Service",
"ICT Training Expenses",
"Rents - ICT Machinery and Equipment",
"Internet Subscription Expenses",
"ICT Consultancy Services",
"Communication Networks",
"Other General Services - ICT Services",
"ICT Software Subscription",
"Cable, Satellite, Telegraph and Radio Expenses",
"ICT Machinery and Equipment",
"Computer Software",
"Website Maintenance",
"ICT Generation, Transmission and Distribution Expenses",
"ICT Research, Exploration and Development Expenses"]

# %%
search = 'Mobile|ICT|Software|Website|Database|Landline|Internet|Cloud|Information and Communication|Communication Equipment|Communication Network|Cable|MITHI|Internet|Computer'
ict_budget_items=all_data[all_data.Objective.str.contains(search,na=0)]
ict_item_department = ict_budget_items.groupby(['Department']).sum()
#ict_item_objectives = ict_budget_items.groupby(['Category','Objective']).sum()
ict_item_objectives = ict_budget_items.groupby(['Objective']).sum()
ict_item_objectives.sort(columns='Amount',ascending=False,inplace=True)
ict_item_department.sort(columns='Amount',ascending=False,inplace=True)
ict_item_objectives['Share %'] = ict_item_objectives['Amount']/ict_item_objectives['Amount'].sum()*100
ict_item_department['Share %'] = ict_item_department['Amount']/ict_item_department['Amount'].sum()*100

# %% [markdown]
# ### ICT-related Descriptions (ICT-related Projects)

# %% [markdown]
# We also looked at programmed ICT projects in the NEP. This differ from above. Project implementation costs will include administrative costs and not only ICT services costs.

# %%
search_data = 'BalinkBayan Portal|Digitization|Software System|Information System|Data banking|Data Management|Knowledge Management|Information Management|Computerization|Information technology'
ict_project_details = all_data[all_data.Description.str.contains(search_data,na=0)]
a=ict_project_details[ict_project_details.NEP=='NEW'][['Department','Description','Amount']].groupby(['Department','Description']).sum()
ict_projects = a.groupby(level=0).agg(['sum','count'])

#ict_project_details.to_csv('ICT Project Details.csv')
ict_descriptions = a.groupby(level=1).agg(['sum','count'])
ict_descriptions.sort([('Amount','sum')],ascending=False,inplace=True)

# %% [markdown]
# ### ICT Expenditure (Auto and New Proposed)

# %%
ict_budget = ict_projects.join(ict_item_department['Amount'],how='right')
ict_budget.fillna(0,inplace=True)
ict_budget.columns = ['Amount of New Project','Count of New Projects','Amount ICT Budget Items']
ict_budget.sort(columns='Amount of New Project',ascending=False,inplace=True)

# %% [markdown]
# The total ICT spending for NEP amounts to the following (in '000' PhP):

# %%
ict_budget.sum()
# Out:
# Amount of New Project      14584751
# Count of New Projects            44
# Amount ICT Budget Items    25165407
# dtype: float64

# %% [markdown]
# ### Get Details of Interesting Projects

# %%
inc = ['Other Executive Offices','Department of Science and Technology (DOST)']
department = 'Other Executive Offices'
ict_project_details[ict_project_details.Department==department].groupby(['Agency','Description']).sum()
# Out:
#                                                                                                                                                                                                                 Amount
# Agency                                                                             Description
# Commission on Filipinos Overseas                                                   BalinkBayan Portal                                                                                                            11361
# Commission on Higher Education                                                     Higher Education Management Information System (HEMIS)                                                                        12040
# Energy Regulatory Commission                                                       Information System Development and Maintenance                                                                                 9499
# Housing and Urban Development Coordinating Council                                 Development of Shelter Monitoring Information System                                                                           2152
# Mindanao Development Authority                                                     Development Planning and Knowledge Management                                                                                 11955
# National Commission for Culture and the Arts-Proper                                Development and maintenance of NCAA Information System which includes Cultural Data Banking and Public Information Services    5821
# National Commission on Muslim Filipinos (Office on Muslim Affairs)                 Planning, Research, Monitoring and Information Systems Management                                                             11078
# National Historical Commission of the Philippines                                  Development and Maintenance of the Information System                                                                           968
# Philippine Commission on Women (National Commission on the Role of Filipino Women) Development of Front-line Services Information Systems                                                                         1101

# %%
descr = 'Information System Development and Maintenance'
ict_project_details[ict_project_details.Description == descr]
# Out:
#                                                Department  \
# 37136   National Economic and Development Authority (N...
# 37504                             Other Executive Offices
# 347834  National Economic and Development Authority (N...
# 347835  National Economic and Development Authority (N...
# 347836  National Economic and Development Authority (N...
# 347837  National Economic and Development Authority (N...
# 347838  National Economic and Development Authority (N...
# 347839  National Economic and Development Authority (N...
# 347840  National Economic and Development Authority (N...
# 347841  National Economic and Development Authority (N...
# 347842  National Economic and Development Authority (N...
# 347843  National Economic and Development Authority (N...
# 347844  National Economic and Development Authority (N...
# 347845  National Economic and Development Authority (N...
# 347846  National Economic and Development Authority (N...
# 347847  National Economic and Development Authority (N...
# 347848  National Economic and Development Authority (N...
# 347849  National Economic and Development Authority (N...
# 347850  National Economic and Development Authority (N...
# 347851  National Economic and Development Authority (N...
# 347852  National Economic and Development Authority (N...
# 347853  National Economic and Development Authority (N...
# 347854  National Economic and Development Authority (N...
# 347855  National Economic and Development Authority (N...
# 347856  National Economic and Development Authority (N...
# 347857  National Economic and Development Authority (N...
# 347858  National Economic and Development Authority (N...
# 347859  National Economic and Development Authority (N...
# 347860  National Economic and Development Authority (N...
# 347861  National Economic and Development Authority (N...
# 352082                            Other Executive Offices
# 352083                            Other Executive Offices
# 352084                            Other Executive Offices
# 352085                            Other Executive Offices
# 352086                            Other Executive Offices
# 352087                            Other Executive Offices
# 352088                            Other Executive Offices
# 352089                            Other Executive Offices
# 352090                            Other Executive Offices
# 352091                            Other Executive Offices
# 352092                            Other Executive Offices
# 352093                            Other Executive Offices
# 352094                            Other Executive Offices
# 352095                            Other Executive Offices
# 352096                            Other Executive Offices
# 352097                            Other Executive Offices
# 352098                            Other Executive Offices
# 352099                            Other Executive Offices
# 352100                            Other Executive Offices
# 352101                            Other Executive Offices
# 352102                            Other Executive Offices
# 352103                            Other Executive Offices
# 352104                            Other Executive Offices
# 352105                            Other Executive Offices
# 352106                            Other Executive Offices
# 352107                            Other Executive Offices
# 352108                            Other Executive Offices
#
#                               Agency  \
# 37136              Tariff Commission
# 37504   Energy Regulatory Commission
# 347834             Tariff Commission
# 347835             Tariff Commission
# 347836             Tariff Commission
# 347837             Tariff Commission
# 347838             Tariff Commission
# 347839             Tariff Commission
# 347840             Tariff Commission
# 347841             Tariff Commission
# 347842             Tariff Commission
# 347843             Tariff Commission
# 347844             Tariff Commission
# 347845             Tariff Commission
# 347846             Tariff Commission
# 347847             Tariff Commission
# 347848             Tariff Commission
# 347849             Tariff Commission
# 347850             Tariff Commission
# 347851             Tariff Commission
# 347852             Tariff Commission
# 347853             Tariff Commission
# 347854             Tariff Commission
# 347855             Tariff Commission
# 347856             Tariff Commission
# 347857             Tariff Commission
# 347858             Tariff Commission
# 347859             Tariff Commission
# 347860             Tariff Commission
# 347861             Tariff Commission
# 352082  Energy Regulatory Commission
# 352083  Energy Regulatory Commission
# 352084  Energy Regulatory Commission
# 352085  Energy Regulatory Commission
# 352086  Energy Regulatory Commission
# 352087  Energy Regulatory Commission
# 352088  Energy Regulatory Commission
# 352089  Energy Regulatory Commission
# 352090  Energy Regulatory Commission
# 352091  Energy Regulatory Commission
# 352092  Energy Regulatory Commission
# 352093  Energy Regulatory Commission
# 352094  Energy Regulatory Commission
# 352095  Energy Regulatory Commission
# 352096  Energy Regulatory Commission
# 352097  Energy Regulatory Commission
# 352098  Energy Regulatory Commission
# 352099  Energy Regulatory Commission
# 352100  Energy Regulatory Commission
# 352101  Energy Regulatory Commission
# 352102  Energy Regulatory Commission
# 352103  Energy Regulatory Commission
# 352104  Energy Regulatory Commission
# 352105  Energy Regulatory Commission
# 352106  Energy Regulatory Commission
# 352107  Energy Regulatory Commission
# 352108  Energy Regulatory Commission
#
#                                            Description  \
# 37136   Information System Development and Maintenance
# 37504   Information System Development and Maintenance
# 347834  Information System Development and Maintenance
# 347835  Information System Development and Maintenance
# 347836  Information System Development and Maintenance
# 347837  Information System Development and Maintenance
# 347838  Information System Development and Maintenance
# 347839  Information System Development and Maintenance
# 347840  Information System Development and Maintenance
# 347841  Information System Development and Maintenance
# 347842  Information System Development and Maintenance
# 347843  Information System Development and Maintenance
# 347844  Information System Development and Maintenance
# 347845  Information System Development and Maintenance
# 347846  Information System Development and Maintenance
# 347847  Information System Development and Maintenance
# 347848  Information System Development and Maintenance
# 347849  Information System Development and Maintenance
# 347850  Information System Development and Maintenance
# 347851  Information System Development and Maintenance
# 347852  Information System Development and Maintenance
# 347853  Information System Development and Maintenance
# 347854  Information System Development and Maintenance
# 347855  Information System Development and Maintenance
# 347856  Information System Development and Maintenance
# 347857  Information System Development and Maintenance
# 347858  Information System Development and Maintenance
# 347859  Information System Development and Maintenance
# 347860  Information System Development and Maintenance
# 347861  Information System Development and Maintenance
# 352082  Information System Development and Maintenance
# 352083  Information System Development and Maintenance
# 352084  Information System Development and Maintenance
# 352085  Information System Development and Maintenance
# 352086  Information System Development and Maintenance
# 352087  Information System Development and Maintenance
# 352088  Information System Development and Maintenance
# 352089  Information System Development and Maintenance
# 352090  Information System Development and Maintenance
# 352091  Information System Development and Maintenance
# 352092  Information System Development and Maintenance
# 352093  Information System Development and Maintenance
# 352094  Information System Development and Maintenance
# 352095  Information System Development and Maintenance
# 352096  Information System Development and Maintenance
# 352097  Information System Development and Maintenance
# 352098  Information System Development and Maintenance
# 352099  Information System Development and Maintenance
# 352100  Information System Development and Maintenance
# 352101  Information System Development and Maintenance
# 352102  Information System Development and Maintenance
# 352103  Information System Development and Maintenance
# 352104  Information System Development and Maintenance
# 352105  Information System Development and Maintenance
# 352106  Information System Development and Maintenance
# 352107  Information System Development and Maintenance
# 352108  Information System Development and Maintenance
#
#                                         Category  \
# 37136                         Personnel Services
# 37504                         Personnel Services
# 347834                        Personnel Services
# 347835                        Personnel Services
# 347836                        Personnel Services
# 347837                        Personnel Services
# 347838                        Personnel Services
# 347839                        Personnel Services
# 347840                        Personnel Services
# 347841                        Personnel Services
# 347842                        Personnel Services
# 347843                        Personnel Services
# 347844  Maintenance and Other Operating Expenses
# 347845  Maintenance and Other Operating Expenses
# 347846  Maintenance and Other Operating Expenses
# 347847  Maintenance and Other Operating Expenses
# 347848  Maintenance and Other Operating Expenses
# 347849  Maintenance and Other Operating Expenses
# 347850  Maintenance and Other Operating Expenses
# 347851  Maintenance and Other Operating Expenses
# 347852  Maintenance and Other Operating Expenses
# 347853  Maintenance and Other Operating Expenses
# 347854  Maintenance and Other Operating Expenses
# 347855  Maintenance and Other Operating Expenses
# 347856  Maintenance and Other Operating Expenses
# 347857  Maintenance and Other Operating Expenses
# 347858  Maintenance and Other Operating Expenses
# 347859  Maintenance and Other Operating Expenses
# 347860  Maintenance and Other Operating Expenses
# 347861  Maintenance and Other Operating Expenses
# 352082                        Personnel Services
# 352083                        Personnel Services
# 352084                        Personnel Services
# 352085                        Personnel Services
# 352086                        Personnel Services
# 352087                        Personnel Services
# 352088                        Personnel Services
# 352089                        Personnel Services
# 352090                        Personnel Services
# 352091                        Personnel Services
# 352092                        Personnel Services
# 352093                        Personnel Services
# 352094  Maintenance and Other Operating Expenses
# 352095  Maintenance and Other Operating Expenses
# 352096  Maintenance and Other Operating Expenses
# 352097  Maintenance and Other Operating Expenses
# 352098  Maintenance and Other Operating Expenses
# 352099  Maintenance and Other Operating Expenses
# 352100  Maintenance and Other Operating Expenses
# 352101  Maintenance and Other Operating Expenses
# 352102  Maintenance and Other Operating Expenses
# 352103  Maintenance and Other Operating Expenses
# 352104  Maintenance and Other Operating Expenses
# 352105  Maintenance and Other Operating Expenses
# 352106  Maintenance and Other Operating Expenses
# 352107  Maintenance and Other Operating Expenses
# 352108  Maintenance and Other Operating Expenses
#
#                                                 Objective  Amount   NEP
# 37136              Retirement and Life Insurance Premiums     103  AUTO
# 37504              Retirement and Life Insurance Premiums     423  AUTO
# 347834                            Basic Salary - Civilian     862   NEW
# 347835                                    PERA - Civilian      72   NEW
# 347836              Clothing/Uniform Allowance - Civilian      15   NEW
# 347837        Productivity Incentive Allowance - Civilian       6   NEW
# 347838                                   Bonus - Civilian      72   NEW
# 347839                               Cash Gift - Civilian      15   NEW
# 347840                                Pag-IBIG - Civilian       4   NEW
# 347841                              PhilHealth - Civilian       9   NEW
# 347842                                    ECIP - Civilian       4   NEW
# 347843   Lump-sum for Step Increments - Length of Service       2   NEW
# 347844                         Traveling Expenses - Local       2   NEW
# 347845                       Traveling Expenses - Foreign      20   NEW
# 347846                                  Training Expenses       5   NEW
# 347847                           Office Supplies Expenses      54   NEW
# 347848                         Accountable Forms Expenses       1   NEW
# 347849                  Fuel, Oil and Lubricants Expenses       5   NEW
# 347850              Other Supplies and Materials Expenses       1   NEW
# 347851                                     Water Expenses       4   NEW
# 347852                               Electricity Expenses      46   NEW
# 347853                                             Mobile       6   NEW
# 347854                                           Landline      12   NEW
# 347855                     Internet Subscription Expenses       4   NEW
# 347856                                          Machinery       4   NEW
# 347857                                   Office Equipment      54   NEW
# 347858                                     Motor Vehicles      47   NEW
# 347859  Repairs and Maintenance -  Furniture and Fixtures       5   NEW
# 347860                    Rents - Building and Structures     502   NEW
# 347861                              Subscription Expenses       5   NEW
# 352082                            Basic Salary - Civilian    3529   NEW
# 352083                                    PERA - Civilian     108   NEW
# 352084                      Representation Allowance (RA)     120   NEW
# 352085                      Transportation Allowance (TA)     120   NEW
# 352086              Clothing/Uniform Allowance - Civilian      45   NEW
# 352087        Productivity Incentive Allowance - Civilian      18   NEW
# 352088                                   Bonus - Civilian     294   NEW
# 352089                               Cash Gift - Civilian      45   NEW
# 352090                                Pag-IBIG - Civilian      11   NEW
# 352091                              PhilHealth - Civilian      34   NEW
# 352092                                    ECIP - Civilian      11   NEW
# 352093   Lump-sum for Step Increments - Length of Service       9   NEW
# 352094                         Traveling Expenses - Local     216   NEW
# 352095                              ICT Training Expenses     377   NEW
# 352096                           Office Supplies Expenses     505   NEW
# 352097                  Fuel, Oil and Lubricants Expenses      36   NEW
# 352098                                     Water Expenses     106   NEW
# 352099                               Electricity Expenses     795   NEW
# 352100                       Postage and Courier Services      20   NEW
# 352101                                             Mobile      24   NEW
# 352102                                           Landline      50   NEW
# 352103                     Internet Subscription Expenses     949   NEW
# 352104              Other General Services - ICT Services     900   NEW
# 352105                               Advertising Expenses      68   NEW
# 352106                  Printing and Publication Expenses      30   NEW
# 352107                              Subscription Expenses      27   NEW
# 352108                          ICT Software Subscription     629   NEW

# %%
descr = 'Information System Development and Maintenance'
descr = 'Information System'
d=ict_project_details[ict_project_details.Description.str.contains(descr)]
d.groupby(['Agency','Objective']).sum()
#e=d.groupby(['Objective']).sum()
d.groupby(['Agency']).sum()
#e.sort(columns='Amount',ascending=False)
#d['Amount'].sum()
# Out:
#                                                                                      Amount
# Agency
# Bureau of Internal Revenue                                                          1201578
# Commission on Elections (COMELEC)                                                    295793
# Commission on Higher Education                                                        12040
# Don Mariano Marcos Memorial State University                                           4975
# Energy Regulatory Commission                                                           9499
# Environmental Management Bureau                                                        5800
# Housing and Urban Development Coordinating Council                                     2152
# Industrial Technology Development Institute                                            6364
# Jose Rizal Memorial State University                                                    586
# Land Registration Authority                                                            2452
# National Commission for Culture and the Arts-Proper                                    5821
# National Commission on Muslim Filipinos (Office on Muslim Affairs)                    11078
# National Historical Commission of the Philippines                                       968
# National Museum                                                                         100
# National Nutrition Council                                                             4723
# National Police Commission                                                             5313
# National Wages and Productivity Commission                                             1020
# Office of the Director-General                                                        10413
# Office of the Ombudsman                                                               26004
# Office of the Secretary                                                              244906
# Philippine Commission on Women (National Commission on the Role of Filipino Women)     1101
# Philippine Information Agency                                                         10353
# Public-Private Partnership Center of the Philippines                                  18668
# Southern Philippines Agri-Business and Marine and Aquatic School of Technology         3573
# Sulu State College                                                                     1016
# Supreme Court of the Philippines and the Lower Courts                                175000
# Tariff Commission                                                                      1941

# %% [markdown]
# ### Telco will get at least the following amount from the government

# %%
ppp = [
"Internet Subscription Expenses",
"Landline","Mobile","Cable, Satellite, Telegraph and Radio Expenses"]

c=all_data[all_data.Objective.isin(ppp)]
c['Amount'].sum()/ict_budget['Amount ICT Budget Items'].sum()*100
#c['Amount'].sum()
# Out:
# 21.179999194926591

# %% [markdown]
# ### Proprietary Software Expenses

# %%
proprietary = [
    'ICT Software Subscription',
    'ICT Software',
    'Computer Software',"Cloud Computing Service",]

proprietary_expenses = all_data[(all_data.Objective.isin(proprietary))]

# %%
proprietary_expenses['Amount'].sum()/ict_budget['Amount ICT Budget Items'].sum()*100
proprietary_expenses['Amount'].sum()
# Out:
# 709468.0

# %%
new_projects = ict_project_details[ict_project_details.NEP=='NEW']

# %% [markdown]
# ### To Outsource or In-house IT for new projects

# %%
benefits = [
       'Basic Salary - Civilian',
       'Retirement and Life Insurance Premiums','Bonus - Civilian',
       'PERA - Civilian',
       'Cash Gift - Civilian', 'Clothing/Uniform Allowance - Civilian',
       'PhilHealth - Civilian',
       'Productivity Incentive Allowance - Civilian',
       'ECIP - Civilian','Pag-IBIG - Civilian',
       'Honoraria - Civilian', 
       'Salaries and Wages - Casual/Contractual']

personnel_benefits = new_projects[new_projects.Objective.isin(benefits)] 

outsourced = [
       'Other General Services - ICT Services',
       'Consultancy Services',
       'ICT Consultancy Services',
       'Cloud Computing Service','Website Maintenance']

outsourced_expenses = new_projects[new_projects.Objective.isin(outsourced)]

# %%
#personnel_benefits['Amount'].sum()/ict_budget['Amount of New Project'].sum()
personnel_benefits['Amount'].sum()
# Out:
# 420913.0

# %%
#outsourced_expenses['Amount'].sum()/ict_budget['Amount of New Project'].sum()
outsourced_expenses['Amount'].sum()
# Out:
# 793460.0

# %% [markdown]
# ### Website Maintenance

# %%
Web_Maintenance = all_data[all_data.Objective=='Website Maintenance']
temp=Web_Maintenance[['Department','Agency','Amount']].groupby(['Department','Agency']).sum()
temp.sort(columns='Amount',ascending=False,inplace=True)
temp
# Out:
#                                                                                                                                                                   Amount
# Department                                             Agency
# Department of National Defense (DND)                   Office of Civil Defense                                                                                      1500
# Department of Environment and Natural Resources (DENR) Office of the Secretary                                                                                       567
# Other Executive Offices                                National Commission for Culture and the Arts-Proper                                                           550
# Department of Budget and Management (DBM)              Government Procurement Policy Board-Technical Support Office                                                  150
# Autonomous Region in Muslim Mindanao (ARMM)            Autonomous Regional Government in Muslim Mindanao                                                             107
# Department of the Interior and Local Government (DILG) National Police Commission                                                                                     66
# Department of National Defense (DND)                   Armed Forces of the Philippines - General Headquarters, AFP and AFP-Wide Service Support Units (AFPWSSUS)      43
# Department of Foreign Affairs (DFA)                    UNESCO National Commission of the Philippines                                                                  25

# %% [markdown]
# ### Rents - ICT Machinery and Equipment

# %%
#Description, Agency, Department, Category
query_str = 'Rents - ICT Machinery and Equipment'
temp = all_data[all_data.Objective==query_str].groupby(['Department','Agency','Description']).sum()
temp.sort(columns='Amount',ascending=False,inplace=True)
#temp
temp.sum()
# Out:
# Amount    2287511
# dtype: float64

# %% [markdown]
# ### ICT Acquisitions

# %%
#Description, Agency, Department, Category
query_str = [
    'Information and Communication Technology Equipment',
    'Communication Equipment',
    'Communication Networks',
    'ICT Machinery and Equipment',
    ]
temp0 = all_data[all_data.Objective.isin(query_str)] 
temp0['Amount'].sum()/all_data['Amount'].sum()*100
temp0.sum()
# Out:
# Amount    14509967
# dtype: float64
